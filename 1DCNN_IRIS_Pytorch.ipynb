# %%
import torch
print(torch.__version__)
import numpy as np
import random
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, TensorDataset, DataLoader
from torch.utils.data import random_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from  sklearn import  datasets
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']
# Out:
# 1.9.0+cu102

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=True)

X_train = X_train.reshape(X_train.shape[0], 4, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 4, 1).astype('float32') 
#y_train = np.array(y_train).reshape(X_train.shape[0], 1)#.astype('float32') 
#y_test = np.array(y_test).reshape(X_test.shape[0], 1)#.astype('float32') 

print("Training Shape", X_train.shape, y_train.shape)
print("Testing Shape", X_test.shape, y_test.shape)
# Out:
# Training Shape (105, 4, 1) (105,)
# Testing Shape (45, 4, 1) (45,)

# %%
from torch.utils.data import Dataset, TensorDataset, DataLoader

class MyDataset(Dataset):
    def __init__(self, data, targets):   #, transform=None
        self.data = data
        self.labels = torch.LongTensor(targets)
        
    def __getitem__(self, index):
        x = self.data[index]
        y = self.labels[index]
        
        x = torch.FloatTensor(x)
        y = torch.from_numpy(np.array(y))
        return x, y
    
    def __len__(self):
        return len(self.data)

def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn

train_dataset = MyDataset(X_train, y_train)
train_dataloader = DataLoader(train_dataset, batch_size=5)
test_dataset = MyDataset(X_test, y_test)
test_dataloader = DataLoader(test_dataset, batch_size=5)

# %%
from torch.autograd import Variable

class OneDCNN(nn.Module):
  def __init__(self, num_classes, in_channels, out_channels, kernel_size=3, stride=1):
    super(OneDCNN,self).__init__()
    self.in_channels = in_channels
    self.out_channels = out_channels
    self.kernel_size = kernel_size
    
    self.conv1d = nn.Conv1d(in_channels, out_channels, kernel_size)
    self.relu = nn.ReLU(inplace=True)
    self.fc1 = nn.Linear(out_channels,50)
    self.fc2 = nn.Linear(50,num_classes)
        
  def forward(self,x):
    x = self.conv1d(x)
    x = self.relu(x)
    x = x.view(x.size(0), -1)
    x = self.fc1(x)
    x = self.relu(x)
    x = self.fc2(x)
        
    return x

  def training_step(self, batch):
    data, labels = batch 
    out = self(data)                  # Generate predictions
    loss = F.cross_entropy(out, labels) # Calculate loss
    acc = accuracy(out, labels)           # Calculate accuracy
    return acc, loss
    
  def validation_step(self, batch):
    data, labels = batch 
    out = self(data)                    # Generate predictions
    loss = F.cross_entropy(out, labels)   # Calculate loss
    acc = accuracy(out, labels)           # Calculate accuracy
    return {'val_loss': loss, 'val_acc': acc}
        
  def validation_epoch_end(self, outputs):
    batch_losses = [x['val_loss'] for x in outputs]
    epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
    batch_accs = [x['val_acc'] for x in outputs]
    epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
    return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
  def epoch_end(self, epoch, result):
    print("Epoch [{}]: train_acc: {:.4f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
        epoch, result['train_acc'], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
train_dl = DeviceDataLoader(train_dataloader, device)
val_dl = DeviceDataLoader(test_dataloader, device)

# %%
num_epochs = 100
learning_rate = 0.001

in_channels = 4
out_channels = 4
kernel_size = 1

num_classes = 3

model = to_device(OneDCNN(num_classes, in_channels, out_channels, kernel_size), device)
model
# Out:
# OneDCNN(
#   (conv1d): Conv1d(4, 4, kernel_size=(1,), stride=(1,))
#   (relu): ReLU(inplace=True)
#   (fc1): Linear(in_features=4, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=3, bias=True)
# )

# %%
def accuracy(outputs, labels):
  _, preds = torch.max(outputs, dim=1)
  return torch.tensor(torch.sum(preds == labels).item() / len(preds))

@torch.no_grad()
def evaluate(model, val_loader):
  outputs = [model.validation_step(batch) for batch in val_loader]
  return model.validation_epoch_end(outputs)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

best_acc = -np.inf
history = []
# Train the model
for epoch in range(num_epochs):
  # Training Phase 
  # model.train()
  train_acc = []
  train_losses = []
  for batch in train_dl:
    acc, loss = model.training_step(batch)
    train_acc.append(acc)
    train_losses.append(loss)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
  # Validation phase
  result = evaluate(model, val_dl)
  result['train_acc'] = torch.stack(train_acc).mean().item()
  result['train_loss'] = torch.stack(train_losses).mean().item()
    
  if result['val_acc']>best_acc:
    best_acc = result['val_acc']
    torch.save(model.state_dict(), '1dcnn-iris.pth')

  model.epoch_end(epoch, result)
  history.append(result)
# Out:
# Epoch [0]: train_acc: 0.3524, train_loss: 1.1158, val_loss: 1.0493, val_acc: 0.5778
# Epoch [1]: train_acc: 0.6762, train_loss: 1.0409, val_loss: 0.9959, val_acc: 0.7556
# Epoch [2]: train_acc: 0.7810, train_loss: 0.9783, val_loss: 0.9355, val_acc: 0.7556
# Epoch [3]: train_acc: 0.8190, train_loss: 0.9111, val_loss: 0.8634, val_acc: 0.7556
# Epoch [4]: train_acc: 0.8286, train_loss: 0.8338, val_loss: 0.7834, val_acc: 0.7556
# Epoch [5]: train_acc: 0.8286, train_loss: 0.7502, val_loss: 0.7042, val_acc: 0.7556
# Epoch [6]: train_acc: 0.8286, train_loss: 0.6668, val_loss: 0.6326, val_acc: 0.7556
# Epoch [7]: train_acc: 0.8476, train_loss: 0.5915, val_loss: 0.5729, val_acc: 0.7778
# Epoch [8]: train_acc: 0.8476, train_loss: 0.5296, val_loss: 0.5243, val_acc: 0.7778
# Epoch [9]: train_acc: 0.8476, train_loss: 0.4813, val_loss: 0.4858, val_acc: 0.7778
# Epoch [10]: train_acc: 0.8476, train_loss: 0.4443, val_loss: 0.4551, val_acc: 0.8000
# Epoch [11]: train_acc: 0.8476, train_loss: 0.4141, val_loss: 0.4305, val_acc: 0.8000
# Epoch [12]: train_acc: 0.8667, train_loss: 0.3899, val_loss: 0.4105, val_acc: 0.8000
# Epoch [13]: train_acc: 0.8667, train_loss: 0.3699, val_loss: 0.3928, val_acc: 0.8000
# Epoch [14]: train_acc: 0.8762, train_loss: 0.3521, val_loss: 0.3773, val_acc: 0.8222
# Epoch [15]: train_acc: 0.8762, train_loss: 0.3365, val_loss: 0.3632, val_acc: 0.8222
# Epoch [16]: train_acc: 0.8762, train_loss: 0.3229, val_loss: 0.3508, val_acc: 0.8222
# Epoch [17]: train_acc: 0.8762, train_loss: 0.3107, val_loss: 0.3395, val_acc: 0.8222
# Epoch [18]: train_acc: 0.8857, train_loss: 0.2994, val_loss: 0.3286, val_acc: 0.8222
# Epoch [19]: train_acc: 0.8857, train_loss: 0.2890, val_loss: 0.3184, val_acc: 0.8222
# Epoch [20]: train_acc: 0.8857, train_loss: 0.2793, val_loss: 0.3088, val_acc: 0.8444
# Epoch [21]: train_acc: 0.8952, train_loss: 0.2700, val_loss: 0.2995, val_acc: 0.8444
# Epoch [22]: train_acc: 0.8952, train_loss: 0.2610, val_loss: 0.2904, val_acc: 0.8444
# Epoch [23]: train_acc: 0.9048, train_loss: 0.2521, val_loss: 0.2809, val_acc: 0.8444
# Epoch [24]: train_acc: 0.9143, train_loss: 0.2432, val_loss: 0.2714, val_acc: 0.8667
# Epoch [25]: train_acc: 0.9238, train_loss: 0.2343, val_loss: 0.2620, val_acc: 0.8889
# Epoch [26]: train_acc: 0.9333, train_loss: 0.2253, val_loss: 0.2523, val_acc: 0.9111
# Epoch [27]: train_acc: 0.9333, train_loss: 0.2161, val_loss: 0.2424, val_acc: 0.9111
# Epoch [28]: train_acc: 0.9333, train_loss: 0.2069, val_loss: 0.2318, val_acc: 0.9111
# Epoch [29]: train_acc: 0.9429, train_loss: 0.1979, val_loss: 0.2211, val_acc: 0.9111
# Epoch [30]: train_acc: 0.9429, train_loss: 0.1889, val_loss: 0.2103, val_acc: 0.9333
# Epoch [31]: train_acc: 0.9429, train_loss: 0.1801, val_loss: 0.1995, val_acc: 0.9333
# Epoch [32]: train_acc: 0.9524, train_loss: 0.1713, val_loss: 0.1887, val_acc: 0.9556
# Epoch [33]: train_acc: 0.9524, train_loss: 0.1632, val_loss: 0.1791, val_acc: 0.9556
# Epoch [34]: train_acc: 0.9429, train_loss: 0.1555, val_loss: 0.1700, val_acc: 0.9556
# Epoch [35]: train_acc: 0.9524, train_loss: 0.1485, val_loss: 0.1615, val_acc: 0.9556
# Epoch [36]: train_acc: 0.9619, train_loss: 0.1420, val_loss: 0.1537, val_acc: 0.9556
# Epoch [37]: train_acc: 0.9619, train_loss: 0.1361, val_loss: 0.1466, val_acc: 0.9556
# Epoch [38]: train_acc: 0.9619, train_loss: 0.1307, val_loss: 0.1400, val_acc: 0.9556
# Epoch [39]: train_acc: 0.9619, train_loss: 0.1258, val_loss: 0.1340, val_acc: 0.9556
# Epoch [40]: train_acc: 0.9619, train_loss: 0.1214, val_loss: 0.1287, val_acc: 0.9556
# Epoch [41]: train_acc: 0.9619, train_loss: 0.1174, val_loss: 0.1239, val_acc: 0.9556
# Epoch [42]: train_acc: 0.9619, train_loss: 0.1138, val_loss: 0.1195, val_acc: 0.9556
# Epoch [43]: train_acc: 0.9619, train_loss: 0.1105, val_loss: 0.1156, val_acc: 0.9556
# Epoch [44]: train_acc: 0.9619, train_loss: 0.1074, val_loss: 0.1121, val_acc: 0.9556
# Epoch [45]: train_acc: 0.9619, train_loss: 0.1045, val_loss: 0.1088, val_acc: 0.9556
# Epoch [46]: train_acc: 0.9619, train_loss: 0.1019, val_loss: 0.1057, val_acc: 0.9556
# Epoch [47]: train_acc: 0.9619, train_loss: 0.0995, val_loss: 0.1029, val_acc: 0.9556
# Epoch [48]: train_acc: 0.9619, train_loss: 0.0972, val_loss: 0.1003, val_acc: 0.9556
# Epoch [49]: train_acc: 0.9619, train_loss: 0.0951, val_loss: 0.0980, val_acc: 0.9556
# Epoch [50]: train_acc: 0.9619, train_loss: 0.0932, val_loss: 0.0958, val_acc: 0.9556
# Epoch [51]: train_acc: 0.9619, train_loss: 0.0913, val_loss: 0.0938, val_acc: 0.9556
# Epoch [52]: train_acc: 0.9619, train_loss: 0.0896, val_loss: 0.0920, val_acc: 0.9556
# Epoch [53]: train_acc: 0.9619, train_loss: 0.0879, val_loss: 0.0903, val_acc: 0.9556
# Epoch [54]: train_acc: 0.9619, train_loss: 0.0864, val_loss: 0.0888, val_acc: 0.9556
# Epoch [55]: train_acc: 0.9619, train_loss: 0.0849, val_loss: 0.0874, val_acc: 0.9556
# Epoch [56]: train_acc: 0.9619, train_loss: 0.0835, val_loss: 0.0861, val_acc: 0.9556
# Epoch [57]: train_acc: 0.9619, train_loss: 0.0822, val_loss: 0.0848, val_acc: 0.9556
# Epoch [58]: train_acc: 0.9619, train_loss: 0.0809, val_loss: 0.0837, val_acc: 0.9556
# Epoch [59]: train_acc: 0.9619, train_loss: 0.0797, val_loss: 0.0827, val_acc: 0.9556
# Epoch [60]: train_acc: 0.9619, train_loss: 0.0786, val_loss: 0.0817, val_acc: 0.9556
# Epoch [61]: train_acc: 0.9619, train_loss: 0.0775, val_loss: 0.0807, val_acc: 0.9556
# Epoch [62]: train_acc: 0.9619, train_loss: 0.0765, val_loss: 0.0798, val_acc: 0.9556
# Epoch [63]: train_acc: 0.9619, train_loss: 0.0755, val_loss: 0.0791, val_acc: 0.9556
# Epoch [64]: train_acc: 0.9619, train_loss: 0.0745, val_loss: 0.0783, val_acc: 0.9556
# Epoch [65]: train_acc: 0.9619, train_loss: 0.0736, val_loss: 0.0777, val_acc: 0.9556
# Epoch [66]: train_acc: 0.9619, train_loss: 0.0727, val_loss: 0.0771, val_acc: 0.9556
# Epoch [67]: train_acc: 0.9619, train_loss: 0.0718, val_loss: 0.0765, val_acc: 0.9556
# Epoch [68]: train_acc: 0.9619, train_loss: 0.0710, val_loss: 0.0760, val_acc: 0.9556
# Epoch [69]: train_acc: 0.9714, train_loss: 0.0701, val_loss: 0.0756, val_acc: 0.9556
# Epoch [70]: train_acc: 0.9714, train_loss: 0.0693, val_loss: 0.0751, val_acc: 0.9556
# Epoch [71]: train_acc: 0.9714, train_loss: 0.0685, val_loss: 0.0746, val_acc: 0.9556
# Epoch [72]: train_acc: 0.9714, train_loss: 0.0678, val_loss: 0.0740, val_acc: 0.9556
# Epoch [73]: train_acc: 0.9714, train_loss: 0.0670, val_loss: 0.0736, val_acc: 0.9556
# Epoch [74]: train_acc: 0.9714, train_loss: 0.0663, val_loss: 0.0731, val_acc: 0.9556
# Epoch [75]: train_acc: 0.9714, train_loss: 0.0656, val_loss: 0.0727, val_acc: 0.9556
# Epoch [76]: train_acc: 0.9714, train_loss: 0.0649, val_loss: 0.0723, val_acc: 0.9556
# Epoch [77]: train_acc: 0.9714, train_loss: 0.0642, val_loss: 0.0720, val_acc: 0.9556
# Epoch [78]: train_acc: 0.9714, train_loss: 0.0635, val_loss: 0.0717, val_acc: 0.9556
# Epoch [79]: train_acc: 0.9714, train_loss: 0.0629, val_loss: 0.0715, val_acc: 0.9556
# Epoch [80]: train_acc: 0.9714, train_loss: 0.0622, val_loss: 0.0714, val_acc: 0.9556
# Epoch [81]: train_acc: 0.9714, train_loss: 0.0615, val_loss: 0.0713, val_acc: 0.9556
# Epoch [82]: train_acc: 0.9714, train_loss: 0.0609, val_loss: 0.0712, val_acc: 0.9556
# Epoch [83]: train_acc: 0.9714, train_loss: 0.0603, val_loss: 0.0711, val_acc: 0.9556
# Epoch [84]: train_acc: 0.9714, train_loss: 0.0597, val_loss: 0.0711, val_acc: 0.9556
# Epoch [85]: train_acc: 0.9810, train_loss: 0.0591, val_loss: 0.0711, val_acc: 0.9556
# Epoch [86]: train_acc: 0.9810, train_loss: 0.0585, val_loss: 0.0711, val_acc: 0.9556
# Epoch [87]: train_acc: 0.9810, train_loss: 0.0579, val_loss: 0.0710, val_acc: 0.9556
# Epoch [88]: train_acc: 0.9810, train_loss: 0.0573, val_loss: 0.0702, val_acc: 0.9556
# Epoch [89]: train_acc: 0.9810, train_loss: 0.0568, val_loss: 0.0702, val_acc: 0.9556
# Epoch [90]: train_acc: 0.9810, train_loss: 0.0563, val_loss: 0.0695, val_acc: 0.9556
# Epoch [91]: train_acc: 0.9810, train_loss: 0.0559, val_loss: 0.0696, val_acc: 0.9556
# Epoch [92]: train_acc: 0.9810, train_loss: 0.0553, val_loss: 0.0690, val_acc: 0.9556
# Epoch [93]: train_acc: 0.9905, train_loss: 0.0549, val_loss: 0.0685, val_acc: 0.9556
# Epoch [94]: train_acc: 0.9905, train_loss: 0.0545, val_loss: 0.0688, val_acc: 0.9556
# Epoch [95]: train_acc: 0.9905, train_loss: 0.0540, val_loss: 0.0684, val_acc: 0.9556
# Epoch [96]: train_acc: 0.9905, train_loss: 0.0536, val_loss: 0.0679, val_acc: 0.9556
# Epoch [97]: train_acc: 0.9905, train_loss: 0.0532, val_loss: 0.0674, val_acc: 0.9556
# Epoch [98]: train_acc: 0.9905, train_loss: 0.0528, val_loss: 0.0670, val_acc: 0.9556
# Epoch [99]: train_acc: 0.9905, train_loss: 0.0524, val_loss: 0.0666, val_acc: 0.9556

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');
    
plot_losses(history)

# %%
accuracies = [x['val_acc'] for x in history]
plt.plot(accuracies, '-x')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy vs. No. of epochs');

# %%
test_loader = DeviceDataLoader(DataLoader(test_dataset, batch_size=10), device)
result = evaluate(model, test_loader)
result
# Out:
# {'val_acc': 0.9399999380111694, 'val_loss': 0.08290161937475204}

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder

plt.figure(figsize=(10, 10))
plt.plot([0, 1], [0, 1], 'k--')

# One hot encoding
enc = OneHotEncoder()
Y_onehot = enc.fit_transform(y_test[:, np.newaxis]).toarray()

filename = "/content/1dcnn-iris.pth" 
model.load_state_dict(torch.load(filename, map_location=device))
print('>loaded %s' % filename)
model.to(device)
model.eval()
#to_device(model, device)

with torch.no_grad():
    y_pred = model(to_device(torch.FloatTensor(X_test), device))
    y_pred = y_pred.cpu().detach().numpy()
    fpr, tpr, threshold = roc_curve(Y_onehot.ravel(), y_pred.ravel())
    
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc(fpr, tpr)))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend();
# Out:
# >loaded /content/1dcnn-iris.pth

# %%
from torch.autograd import Variable

file_name = "/content/1dcnn-iris.pth" 
#model = LSTM(num_classes, input_size, hidden_size, num_layers)
model.load_state_dict(torch.load(file_name))
print('>loaded %s' % file_name)
model.eval()

# Prediction
my_test = Variable(torch.from_numpy(X_test)).float()
model.to(device)
pred = model(to_device(my_test, device))
pred = pred.cpu().detach().numpy()
pred
# Out:
# >loaded /content/1dcnn-iris.pth
# array([[ 6.7500696 , -4.0792084 , -8.716827  ],
#        [-0.9561133 ,  1.7890706 , -1.3765395 ],
#        [-2.5430958 ,  1.2458416 ,  0.35402447],
#        [ 5.897292  , -3.3694701 , -7.7223725 ],
#        [-5.8203344 ,  0.22115336,  2.753671  ],
#        [-2.9767642 ,  1.0404797 ,  0.723459  ],
#        [-5.548086  ,  0.37485424,  3.2137012 ],
#        [ 5.142126  , -2.769493  , -6.869877  ],
#        [ 3.860781  , -1.7582047 , -5.4378695 ],
#        [-6.047629  ,  0.22139567,  3.628973  ],
#        [-2.1982205 ,  1.8122692 , -0.10769048],
#        [ 5.6943192 , -3.2310295 , -7.5173726 ],
#        [-5.963333  ,  0.30589128,  3.5702412 ],
#        [-2.6092048 ,  1.1705227 ,  0.3988505 ],
#        [-2.9485261 ,  1.3402432 ,  0.7040927 ],
#        [ 3.9117374 , -1.7946768 , -5.4899726 ],
#        [-1.8486362 ,  1.9248018 , -0.4695928 ],
#        [-2.708215  ,  1.4507468 ,  0.45391083],
#        [ 4.388341  , -2.137412  , -5.983832  ],
#        [ 4.1976285 , -1.9997578 , -5.7838283 ],
#        [-2.2403584 ,  1.8850467 , -0.10836027],
#        [-2.6601393 ,  1.5177169 ,  0.39287972],
#        [-4.137767  ,  0.7845259 ,  1.9010108 ],
#        [ 4.718825  , -2.3757846 , -6.331322  ],
#        [-5.3978443 ,  0.3351606 ,  2.9451118 ],
#        [-1.9513415 ,  1.79771   , -0.32909256],
#        [ 7.04957   , -4.327344  , -9.062065  ],
#        [ 5.4939623 , -3.0240176 , -7.2406135 ],
#        [-2.532588  ,  1.5124621 ,  0.28044242],
#        [-4.532692  ,  1.1550674 ,  2.1505454 ],
#        [-2.675845  ,  1.3304508 ,  0.4543867 ],
#        [-6.724515  ,  0.07391787,  4.166558  ],
#        [-1.5217967 ,  2.055558  , -0.8674203 ],
#        [-5.5143056 ,  0.68897766,  3.1102457 ],
#        [-5.3688364 ,  0.8926443 ,  2.9270914 ],
#        [ 5.4686365 , -3.0064301 , -7.214703  ],
#        [-2.0424845 ,  2.125228  , -0.4522906 ],
#        [ 4.638708  , -2.317998  , -6.247082  ],
#        [-3.3393342 ,  1.155375  ,  1.1107711 ],
#        [-5.2689013 ,  0.8827412 ,  2.8458614 ],
#        [-5.5186057 ,  0.45544755,  3.1783304 ],
#        [ 4.7024174 , -2.3639507 , -6.3140707 ],
#        [-3.5985801 ,  1.7291217 ,  1.0999953 ],
#        [-4.8977766 ,  0.7574127 ,  2.575317  ],
#        [-2.6611757 ,  1.2744709 ,  0.45700192]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
print ("The accuracy is", accuracy_score(y_test, np.argmax(pred, axis=1)))
# Out:
# The accuracy is 0.9555555555555556

# %%
np.argmax(pred, axis=1)
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2, 1, 2, 1, 2, 2, 0, 1, 0, 1, 2, 2, 0, 1, 2,
#        1])

# %%
y_test
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        1, 0, 2, 1, 0, 0, 1, 2, 1, 2, 1, 2, 2, 0, 1, 0, 1, 2, 2, 0, 2, 2,
#        1])

# %%
# Checking for a single instance / predicted class label
k = 44
test0 = torch.reshape(Variable(torch.Tensor(X_test[k])), (1, 4, 1)).float()
model.to(device)
pred = model(to_device(test0, device))
pred = pred.cpu().detach().numpy()
pred
# Out:
# array([[-2.6611755,  1.2744709,  0.4570018]], dtype=float32)

# %%
pred = np.argmax(pred, axis=1)
pred[0]
# Out:
# 1

# %%
# Actual class label
y_test[k]
# Out:
# 1
